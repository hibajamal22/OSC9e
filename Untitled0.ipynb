# %% [markdown]
# <a href="https://colab.research.google.com/github/hibajamal22/OSC9e/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters() 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Out:
# Setup Complete

# %%
fifa_filepath = "/content/fifa.csv" 
fifa_data = pd.read_csv(fifa_filepath)
fifa_data.head()
# Out:
#        Date  ARG  BRA  ESP  FRA  GER  ITA
# 0    8/8/93    5    8   13   12    1    2
# 1   9/23/93   12    1   14    7    5    2
# 2  10/22/93    9    1    7   14    4    3
# 3  11/19/93    9    4    7   15    3    1
# 4  12/23/93    8    3    5   15    1    2

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=fifa_data)
# Out:
# <Axes: >
